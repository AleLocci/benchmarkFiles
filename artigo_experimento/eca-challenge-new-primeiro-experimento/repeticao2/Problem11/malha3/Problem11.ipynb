# %%
#Problema 11
library(dplyr)
numCond <- read.csv(file = 'numCond.csv')

# %%
df_if = data.frame(numCond)
glimpse(df_if)
# Out:
# Observations: 197
# Variables: 1
# $ numCondByDeci <int> 6, 8, 7, 7, 7, 8, 7, 7, 6, 7, 6, 7, 7, 8, 8, 7, 7, 7, 7…

# %%
summary(df_if)
# Out:
#  numCondByDeci
#  Min.   : 1.000
#  1st Qu.: 7.000
#  Median : 8.000
#  Mean   : 8.371
#  3rd Qu.: 9.000
#  Max.   :15.000

# %%
hist(df_if$numCondByDeci)
# Out:
# Plot with title “Histogram of df_if$numCondByDeci”
